# %% [markdown]
# # 00 — Environment Setup
#
# Install dependencies, mount Google Drive, verify all raw data files are accessible.

# %% [markdown]
# ## Data Inputs
# - `requirements.txt`
# - Google Drive / local `data/raw/` folder
#
# ## Data Outputs
# - Verified environment with all packages installed
# - Confirmation that all raw data files are accessible

# %%
# TODO: implement

# Install dependencies (uncomment for Colab)
# !pip install -r ../requirements.txt

import sys
print(f'Python {sys.version}')
# Out:
# ...
#   Using cached patsy-1.0.2-py2.py3-none-any.whl.metadata (3.6 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 593.6/593.6 kB 4.5 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 9.7 MB/s  0:00:00m eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 9.5 MB/s  0:00:01eta 0:00:01m
# Using cached patsy-1.0.2-py2.py3-none-any.whl (233 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [pmdarima]3/4 [pmdarima]ls]
# ...
# Python 3.12.13 | packaged by Anaconda, Inc. | (main, Mar 19 2026, 20:12:32) [Clang 20.1.8 ]
