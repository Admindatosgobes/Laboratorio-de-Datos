# %% [markdown]
# # 02 — EV Projection Fork (MANDATORY)
#
# Run the datos.gob.es Exercise 3 EV growth model. Extract the 2027 projected EV fleet number for Spain.
#
# **This is MANDATORY** — the output feeds directly into File 1 and the demand model.

# %% [markdown]
# ## Data Inputs
# - `data/raw/datos_gob_ev_forecast/` — parquet files from datos.gob.es GitHub fork
# - DGT vehicle registration parquet files (2015-2023)
#
# ## Data Outputs
# - `data/processed/ev_projection_2027.csv` — EV fleet projection by year
# - `total_ev_projected_2027` scalar value (used in File_1.csv)

# %%
import sys
import os
sys.path.insert(0, os.path.join(os.path.dirname(os.getcwd()), ''))
if os.path.basename(os.getcwd()) == 'notebooks':
    os.chdir('..')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

PROCESSED = Path('data/processed')

# Load the cleaned monthly EV registration time series from Notebook 01
ev = pd.read_csv(PROCESSED / 'ev_monthly_registrations.csv', parse_dates=['date'])
ev = ev.set_index('date')['ev_registrations']
print(f"Monthly BEV+PHEV registrations: {len(ev)} months ({ev.index.min()} – {ev.index.max()})")
print(f"Total registrations: {ev.sum():,}")
print("\nLast 6 months:")
print(ev.tail(6))

plt.figure(figsize=(12, 4))
plt.plot(ev.index, ev.values)
plt.title('Monthly BEV+PHEV New Registrations in Spain (2015–2023)')
plt.ylabel('Registrations')
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# Monthly BEV+PHEV registrations: 108 months (2015-01-01 00:00:00 – 2023-12-01 00:00:00)
# Total registrations: 457,153
#
# Last 6 months:
# date
# 2023-07-01    11121
# 2023-08-01     9043
# 2023-09-01    10385
# 2023-10-01    13806
# 2023-11-01    14390
# 2023-12-01    14701
# Name: ev_registrations, dtype: int64

# %% [markdown]
# ## SARIMA Model Fitting
#
# We use `pmdarima.auto_arima` on the log-transformed series to capture the exponential growth trend and seasonal patterns (12-month cycle). This follows the methodology from the datos.gob.es Exercise 3 fork.

# %%
import pmdarima as pm
from statsmodels.tsa.stattools import adfuller

# Log-transform (handles exponential growth better)
log_ev = np.log(ev.values)

# ADF test on log series
adf_result = adfuller(log_ev)
print(f"ADF Statistic: {adf_result[0]:.4f}")
print(f"p-value: {adf_result[1]:.4f}")
print(f"Series is {'stationary' if adf_result[1] < 0.05 else 'non-stationary (needs differencing)'}")

# Fit SARIMA with auto_arima
print("\nFitting SARIMA model (this may take a minute)...")
model = pm.auto_arima(
    log_ev,
    seasonal=True,
    m=12,
    test='adf',
    stepwise=True,
    trace=True,
    error_action='ignore',
    suppress_warnings=True,
)

print(f"\nBest model: {model.order} x {model.seasonal_order}")
print(model.summary())
# Out:
# ADF Statistic: -1.7295
# p-value: 0.4160
# Series is non-stationary (needs differencing)
#
# Fitting SARIMA model (this may take a minute)...
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[12] intercept   : AIC=86.298, Time=0.28 sec
#  ARIMA(0,1,0)(0,0,0)[12] intercept   : AIC=128.316, Time=0.01 sec
#  ARIMA(1,1,0)(1,0,0)[12] intercept   : AIC=110.346, Time=0.04 sec
#  ARIMA(0,1,1)(0,0,1)[12] intercept   : AIC=91.320, Time=0.04 sec
#  ARIMA(0,1,0)(0,0,0)[12]             : AIC=127.511, Time=0.00 sec
#  ARIMA(2,1,2)(0,0,1)[12] intercept   : AIC=93.535, Time=0.17 sec
#  ARIMA(2,1,2)(1,0,0)[12] intercept   : AIC=92.211, Time=0.21 sec
#  ARIMA(2,1,2)(2,0,1)[12] intercept   : AIC=87.959, Time=0.60 sec
#  ARIMA(2,1,2)(1,0,2)[12] intercept   : AIC=87.991, Time=0.57 sec
#  ARIMA(2,1,2)(0,0,0)[12] intercept   : AIC=94.112, Time=0.06 sec
#  ARIMA(2,1,2)(0,0,2)[12] intercept   : AIC=91.068, Time=0.44 sec
#  ARIMA(2,1,2)(2,0,0)[12] intercept   : AIC=88.353, Time=0.51 sec
#  ARIMA(2,1,2)(2,0,2)[12] intercept   : AIC=89.856, Time=1.30 sec
#  ARIMA(1,1,2)(1,0,1)[12] intercept   : AIC=84.031, Time=0.22 sec
#  ARIMA(1,1,2)(0,0,1)[12] intercept   : AIC=91.701, Time=0.10 sec
#  ARIMA(1,1,2)(1,0,0)[12] intercept   : AIC=90.280, Time=0.13 sec
#  ARIMA(1,1,2)(2,0,1)[12] intercept   : AIC=85.797, Time=0.53 sec
#  ARIMA(1,1,2)(1,0,2)[12] intercept   : AIC=85.815, Time=0.51 sec
#  ARIMA(1,1,2)(0,0,0)[12] intercept   : AIC=92.626, Time=0.04 sec
#  ARIMA(1,1,2)(0,0,2)[12] intercept   : AIC=89.112, Time=0.32 sec
#  ARIMA(1,1,2)(2,0,0)[12] intercept   : AIC=86.439, Time=0.39 sec
#  ARIMA(1,1,2)(2,0,2)[12] intercept   : AIC=87.855, Time=0.66 sec
#  ARIMA(0,1,2)(1,0,1)[12] intercept   : AIC=82.133, Time=0.16 sec
#  ARIMA(0,1,2)(0,0,1)[12] intercept   : AIC=89.701, Time=0.05 sec
#  ARIMA(0,1,2)(1,0,0)[12] intercept   : AIC=88.311, Time=0.09 sec
#  ARIMA(0,1,2)(2,0,1)[12] intercept   : AIC=83.852, Time=0.46 sec
#  ARIMA(0,1,2)(1,0,2)[12] intercept   : AIC=83.845, Time=0.56 sec
#  ARIMA(0,1,2)(0,0,0)[12] intercept   : AIC=90.702, Time=0.02 sec
#  ARIMA(0,1,2)(0,0,2)[12] intercept   : AIC=87.142, Time=0.70 sec
#  ARIMA(0,1,2)(2,0,0)[12] intercept   : AIC=84.563, Time=0.33 sec
#  ARIMA(0,1,2)(2,0,2)[12] intercept   : AIC=85.965, Time=0.56 sec
#  ARIMA(0,1,1)(1,0,1)[12] intercept   : AIC=84.509, Time=0.16 sec
#  ARIMA(0,1,3)(1,0,1)[12] intercept   : AIC=84.229, Time=0.45 sec
#  ARIMA(1,1,1)(1,0,1)[12] intercept   : AIC=82.214, Time=0.31 sec
#  ARIMA(1,1,3)(1,0,1)[12] intercept   : AIC=85.878, Time=0.28 sec
#  ARIMA(0,1,2)(1,0,1)[12]             : AIC=inf, Time=0.13 sec
#
# Best model:  ARIMA(0,1,2)(1,0,1)[12] intercept
# Total fit time: 11.451 seconds
#
# Best model: (0, 1, 2) x (1, 0, 1, 12)
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                                    y   No. Observations:                  108
# Model:             SARIMAX(0, 1, 2)x(1, 0, [1], 12)   Log Likelihood                 -35.067
# Date:                              Sun, 15 Mar 2026   AIC                             82.133
# Time:                                      10:13:28   BIC                             98.170
# Sample:                                           0   HQIC                            88.635
#                                               - 108
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0018      0.006      0.284      0.776      -0.011       0.014
# ma.L1         -0.6047      0.090     -6.725      0.000      -0.781      -0.428
# ma.L2         -0.2104      0.129     -1.630      0.103      -0.463       0.043
# ar.S.L12       0.9555      0.154      6.201      0.000       0.654       1.258
# ma.S.L12      -0.8352      0.323     -2.588      0.010      -1.468      -0.203
# sigma2         0.1074      0.012      9.253      0.000       0.085       0.130
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):               400.06
# Prob(Q):                              0.92   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.62   Skew:                            -1.76
# Prob(H) (two-sided):                  0.16   Kurtosis:                        11.79
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# ## Forecast 2024–2027
#
# Forecast 48 months forward (Jan 2024 – Dec 2027). Convert back from log scale. Compute cumulative EV fleet to get `total_ev_projected_2027`.

# %% [markdown]
# 1. **Why are we doing data splitting before processing the text?**
#
#
# 2. Which NB library will be using according to the distribution of classes?
# 3. Why we don ́t use ‘fit’ in the test dataset?
# 4. Why micro-recall & micro-precision are not shown in classification report?
# 5. Which approach produces best results? Which are your best TF-IDF parameters?
# 6. Which is the class more difficult to predict and why might be?
# 7. Why one class appears easier to predict and the 2 others get confused?
# 8. Which are the top 10 words that identify each author?
# Exercise – Naïve Bayes 3 classes

# %%
# Forecast 48 months ahead (2024-01 to 2027-12)
n_forecast = 48
log_forecast, conf_int = model.predict(n_periods=n_forecast, return_conf_int=True)

# Convert from log scale
forecast = np.exp(log_forecast)
ci_lower = np.exp(conf_int[:, 0])
ci_upper = np.exp(conf_int[:, 1])

# Create forecast dates
forecast_dates = pd.date_range(start='2024-01-01', periods=n_forecast, freq='MS')

# Combine actual + forecast
full_series = pd.DataFrame({
    'date': list(ev.index) + list(forecast_dates),
    'ev_registrations': list(ev.values) + list(forecast.astype(int)),
    'type': ['actual'] * len(ev) + ['forecast'] * n_forecast,
})
full_series['cumulative_ev_fleet'] = full_series['ev_registrations'].cumsum()

# Extract the key number
total_ev_projected_2027 = int(full_series['cumulative_ev_fleet'].iloc[-1])
print(f"total_ev_projected_2027 = {total_ev_projected_2027:,}")
print(f"\nForecast summary (annual new registrations):")
for year in [2024, 2025, 2026, 2027]:
    mask = full_series['date'].dt.year == year
    print(f"  {year}: {full_series.loc[mask, 'ev_registrations'].sum():,}")

# Plot
fig, axes = plt.subplots(1, 2, figsize=(16, 5))

ax = axes[0]
actual = full_series[full_series['type'] == 'actual']
fcast = full_series[full_series['type'] == 'forecast']
ax.plot(actual['date'], actual['ev_registrations'], label='Actual', color='blue')
ax.plot(fcast['date'], fcast['ev_registrations'], label='Forecast', color='red', linestyle='--')
ax.fill_between(forecast_dates, ci_lower, ci_upper, alpha=0.2, color='red')
ax.set_title('Monthly BEV+PHEV Registrations — Actual vs Forecast')
ax.set_ylabel('Registrations')
ax.legend()
ax.grid(True, alpha=0.3)

ax = axes[1]
ax.plot(full_series['date'], full_series['cumulative_ev_fleet'])
ax.axvline(x=pd.Timestamp('2027-12-31'), color='red', linestyle=':', label='2027 target')
ax.set_title(f'Cumulative EV Fleet → {total_ev_projected_2027:,} by 2027')
ax.set_ylabel('Cumulative Fleet')
ax.legend()
ax.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Save Projection Output

# %%
# Save the full projection
full_series.to_csv(PROCESSED / 'ev_projection_2027.csv', index=False)
print(f"Saved: ev_projection_2027.csv ({full_series.shape[0]} rows)")
print(f"\ntotal_ev_projected_2027 = {total_ev_projected_2027:,}")
print("This value goes into File 1 (Global Network KPIs)")

# Verify the output structure
print(f"\nOutput structure:")
print(full_series.info())
print(f"\nLast 12 months of forecast:")
full_series.tail(12)
